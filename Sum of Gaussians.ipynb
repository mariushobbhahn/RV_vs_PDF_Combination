# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm
from scipy.stats import multivariate_normal as mv_norm

# %%
m1, s1 = -2, 1
m2, s2 = 1, 2

x1 = np.linspace(-3, 3, 1000+1)
x2 = np.linspace(-5, 8, 1000+1)

m_sum = m1+m2
s_sum = np.sqrt(s1**2 + s2**2)

x_sum = np.linspace(-8, 10, 1000+1)

num_samples = 10000
num_bins = int(np.sqrt(num_samples))

#plot one
norm1_pdf = norm.pdf(x_sum, m1, s1)
norm2_pdf = norm.pdf(x_sum, m2, s2)
norm1_samples = norm.rvs(m1, s1, size=num_samples)
norm2_samples = norm.rvs(m2, s2, size=num_samples)
norm1_samples_many = norm.rvs(m1, s1, size=num_samples*100)
norm2_samples_many = norm.rvs(m2, s2, size=num_samples*100)

#plot two
norm_sum_pdf = norm.pdf(x_sum, m_sum, s_sum)
norm_sum_samples = norm1_samples + norm2_samples

#plot three: joint
mu_joint = np.array([m1, m2])
Sigma_joint = np.array([[s1**2, 0], [0, s2**2]])
norm_joint_samples = mv_norm.rvs(mu_joint, Sigma_joint, size=num_samples*100)
x_G = norm_joint_samples[:,0]
y_G = norm_joint_samples[:,1]

#plot three: sum of pdfs
norm_pdf_sum = np.array([norm.pdf(x_, m1, s1) + norm.pdf(x_, m2, s2) for x_ in x_sum])

# %%
# plot sum of Gaussian RVs vs sum of Gaussian pdfs

fig, ax = plt.subplots(1, 3, figsize=(15, 4))

plt.rc('xtick', labelsize=14)
plt.rc('ytick', labelsize=14)
plt.rc('axes', labelsize=14)
legend_size=15

ax[0].plot(x_sum, norm1_pdf, color='blue', label='$\mathcal{N}(x_1; \mu_1, \sigma_1)$')
ax[0].plot(x_sum, norm2_pdf, color='orange', label='$\mathcal{N}(x_2; \mu_2, \sigma_2)$')
ax[0].hist(norm1_samples, bins=num_bins, color='blue', alpha=0.5, density=True)
ax[0].hist(norm2_samples, bins=num_bins, color='orange', alpha=0.5, density=True)
ax[0].legend(loc='upper right', prop={'size': legend_size})

ax[1].plot(x_sum, norm_sum_pdf, color='firebrick', label='$\mathcal{N}(x_1 + x_2; \mu_1 + \mu_2, \sqrt{\sigma_1^2 + \sigma_2^2})$')
ax[1].hist(norm_sum_samples, bins=num_bins, color='firebrick', alpha=0.7, density=True)
ax[1].legend(loc='upper right', prop={'size': legend_size})

ax[2].plot(x_sum, norm_pdf_sum, color='black', label='sum of pdfs')
ax[2].hist(norm_sum_samples, bins=num_bins, color='firebrick', alpha=0.6, density=True)
ax[2].hist(norm1_samples, bins=num_bins, color='blue', alpha=0.3, density=True)
ax[2].hist(norm2_samples, bins=num_bins, color='orange', alpha=0.3, density=True)
ax[2].legend(loc='upper right', prop={'size': legend_size})

plt.tight_layout()
plt.savefig('Gaussian_RV_pdf_sum.png')
plt.show();

# %%
from scipy.integrate import quad

# %%
# plot the convolution of the two Gaussians

x_ = np.linspace(-15, 10, 1000+1)
norm2 = norm.pdf(x_, m2, s2)
norm12_sum = norm.pdf(x_, m_sum, s_sum)

num_steps = 50

int_list = []
m_list = []

for i in range(num_steps+1):
    
    plt.figure(figsize=(10,5))
    plt.plot(x_, norm2, color='orange')
    
    m_ = -15 + 25*i/num_steps
    norm1 = norm.pdf(x_, m_, s1)
    plt.plot(x_, norm1, color='blue')
    #plt.plot(x_, norm12_sum, color='firebrick')
    #f = lambda x: np.min([norm.pdf(x, m_, s1), norm.pdf(x, m2, s2)])
    f = lambda x: norm.pdf(m_ - x, m1, s1) * norm.pdf(x, m2, s2)
    integral, _ = quad(f, -100, 100)
    int_list.append(integral)
    m_list.append(m_)
    for i in range(len(int_list)):    
        plt.axvline(m_list[i], 0.05, 0.05+int_list[i]/0.44, color='firebrick')
    plt.fill_between(x_, np.zeros(len(x_)), np.min([norm1, norm2], 0), color='firebrick', alpha=0.5)
    plt.show()

# %%
# plot the transformed version of the Gaussian
import matplotlib.gridspec as gridspec

x_l, x_u = -5, 1
y_l, y_u = -3, 5

norm12_samples_many = norm1_samples_many + norm2_samples_many
x_marginalx = np.linspace(x_l, x_u, 1000+1)
marginalx_pdf = norm.pdf(x_marginalx, m1, s1)

x_marginaly = np.linspace(y_l, y_u, 1000+1)
marginaly_pdf = norm.pdf(x_marginaly, m2, s2)

# plot everything
fig = plt.figure(1, figsize=(15,6))
# set up subplot grid
gridspec.GridSpec(4,9,hspace=10, wspace=10)

# top left: joint Gaussian
plt.subplot2grid((4,9), (0,0), colspan=3, rowspan=3)

plt.rc('xtick', labelsize=15)
plt.rc('ytick', labelsize=15)
plt.rc('axes', labelsize=15)
plt.hist2d(x_G, y_G, range=[[x_l, x_u],[y_l, y_u]],bins=[50,50], cmap='plasma', density = True)
plt.xlabel('$x_1$', size=20)
plt.ylabel('$x_2$', size=20)

#marginal for x
plt.subplot2grid((4,9), (3,0), colspan=3, rowspan=1)
plt.hist(norm1_samples, range=[x_l, x_u], bins=100, density=True, color='blue', alpha=0.6)
plt.xlim(x_l, x_u)
plt.xticks([])
plt.yticks([])

#marginal for y 
plt.subplot2grid((4,9), (0,3), colspan=1, rowspan=3)
plt.hist(y_G, range=[y_l, y_u], bins=100, density=True, color='orange', alpha=0.6, orientation='horizontal')
plt.ylim(y_l, y_u)
plt.xticks([])
plt.yticks([])

xy_l, xy_u = -7, 5

# middle right: transformed joint Gaussian
plt.subplot2grid((4, 9), (0,4), colspan=4, rowspan=3)

plt.rc('xtick', labelsize=15)
plt.rc('ytick', labelsize=15)
plt.rc('axes', labelsize=15)

plt.hist2d(norm12_samples_many, norm2_samples_many, range=[[xy_l, xy_u],[y_l, y_u]],bins=[50,50], cmap='plasma', density = True)
plt.xlabel('$x_1 + x_2$', size=20)
plt.ylabel('$x_2$', size=20)

# marginal for x+y
plt.subplot2grid((4, 9), (3,4), colspan=4, rowspan=1)
plt.hist(norm12_samples_many, range=[xy_l, xy_u], bins=num_bins, color='red', alpha=0.7, density=True)
plt.xlim(xy_l, xy_u)
plt.xticks([])
plt.yticks([])

#marginal for y 
plt.subplot2grid((4,9), (0,8), colspan=1, rowspan=3)
plt.hist(norm2_samples, range=[y_l, y_u], bins=100, density=True, color='orange', alpha=0.6, orientation='horizontal')
plt.ylim(y_l, y_u)
plt.xticks([])
plt.yticks([])

plt.tight_layout()
plt.savefig('Gaussian_joint_sum.png')
plt.show();
